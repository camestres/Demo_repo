# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

# %%
df = pd.read_csv(f'/content/in_actions.csv', index_col=0)
df_rfm = df.copy() # заготовим датасет для последущей RFM-сегментации

# %%
df.head().T
# Out:
# id                                                1                        2  \
# vydacha_dt                  2019-01-30 00:00:00.000  2021-11-12 00:00:00.000
# activation_dt               2021-11-22 00:00:00.000  2021-11-12 00:00:00.000
# pro0                                              1                        0
# pro1                                              1                        0
# pro2                                              1                        1
# chastotta                                secondhalf                firsthalf
# tran_type_month0                               CRED                 CRED+DEB
# tran_type_month1                           CRED+DEB                 CRED+DEB
# tran_type_month2                               CRED                     CRED
# FREE_LIMIT0                                 3928.86                  14520.0
# FREE_LIMIT1                                 3377.52                 17162.56
# FREE_LIMIT2                                 6610.81                 16002.56
# limit                                       21000.0                  75000.0
# login_0                                         6.0                      6.0
# login_1                                         NaN                     32.0
# login_2                                         NaN                     24.0
# withdraw0                         62,77132906990466                        0
# withdraw1                         66,77646944125122                        0
# withdraw2                         27,17490467431653                        0
# cred_tran_nopartnershare0                      0.08                      NaN
# cred_tran_nopartnershare1                       0.5                      NaN
# cred_tran_nopartnershare2                      0.88                      NaN
# cl_age                                           66                       54
# GENDER_ID                                       1.0                      2.0
# tran_prod                                       2.0                      0.0
# tran_remont                                     0.0                      0.0
# tran_inet                                       0.0                      0.0
# CRED_TRAN_TOTAL                                   1                        1
# CREDIT_TRAN_AMT_last_month                  6181.07                   1160.0
# CL_CHILDREN_NO                                 -1.0                      0.0
# City_Population_category              300 – 700 тыс              0 – 100 тыс
# cl_income                                 1176000.0                 444000.0
# count_tran2                                      17                        4
# counttran1                                        7                        4
# count_tran0                                       7                       14
# tran_amt2                                   6181.07                   1160.0
# tran_amt1                                   6698.46                   1700.0
# tran_amt0                                  17071.14                 76862.33
# avg_amt_prod_3m                              335.94                      NaN
# avg_amt_vnebs_3m                             411.07                      NaN
# avg_amt_avto_3m                                 NaN                      NaN
# avg_amt_inet_3m                                 NaN                      NaN
# churn                                             0                        0
# product_type                              card only         only self pickup
# top_cat                                    Products                Furniture
#
# id                                                3                        4  \
# vydacha_dt                  2021-06-17 00:00:00.000  2021-11-08 00:00:00.000
# activation_dt               2021-11-22 00:00:00.000  2021-11-08 00:00:00.000
# pro0                                              1                        1
# pro1                                              1                        1
# pro2                                              1                        1
# chastotta                                secondhalf               secondhalf
# tran_type_month0                               CRED                 CRED+DEB
# tran_type_month1                               CRED                 CRED+DEB
# tran_type_month2                               CRED                 CRED+DEB
# FREE_LIMIT0                                14869.29                  90000.0
# FREE_LIMIT1                                45149.45                  90000.0
# FREE_LIMIT2                                40638.27                 83629.25
# limit                                       75000.0                  90000.0
# login_0                                         7.0                     11.0
# login_1                                        27.0                     21.0
# login_2                                        10.0                     15.0
# withdraw0                         9,277231048321518                        0
# withdraw1                         9,579041518797426                        0
# withdraw2                                         0                        0
# cred_tran_nopartnershare0                      0.34                      NaN
# cred_tran_nopartnershare1                      0.78                     0.19
# cred_tran_nopartnershare2                      0.75                     0.29
# cl_age                                           54                       40
# GENDER_ID                                       2.0                      2.0
# tran_prod                                       2.0                     33.0
# tran_remont                                     0.0                      0.0
# tran_inet                                       0.0                      1.0
# CRED_TRAN_TOTAL                                   1                        1
# CREDIT_TRAN_AMT_last_month                 15111.64                  9157.78
# CL_CHILDREN_NO                                 -1.0                      0.0
# City_Population_category              300 – 700 тыс              0 – 100 тыс
# cl_income                                  960000.0                 744000.0
# count_tran2                                      10                       18
# counttran1                                        2                       75
# count_tran0                                      16                       28
# tran_amt2                                  15111.64                  8928.04
# tran_amt1                                    719.35                 69845.52
# tran_amt0                                  60130.71                 15572.95
# avg_amt_prod_3m                               199.0                   400.65
# avg_amt_vnebs_3m                             903.55                   612.68
# avg_amt_avto_3m                                 NaN                   749.78
# avg_amt_inet_3m                                 NaN                      NaN
# churn                                             0                        0
# product_type                       only self pickup              plus credit
# top_cat                                    Products                 Products
#
# id                                                5
# vydacha_dt                  2021-11-28 00:00:00.000
# activation_dt               2021-11-28 00:00:00.000
# pro0                                              1
# pro1                                              1
# pro2                                              1
# chastotta                                secondhalf
# tran_type_month0                               CRED
# tran_type_month1                               CRED
# tran_type_month2                               CRED
# FREE_LIMIT0                                 44950.0
# FREE_LIMIT1                                  346.72
# FREE_LIMIT2                                  167.87
# limit                                       45000.0
# login_0                                        11.0
# login_1                                         6.0
# login_2                                        16.0
# withdraw0                                         0
# withdraw1                                         0
# withdraw2                                         0
# cred_tran_nopartnershare0                       NaN
# cred_tran_nopartnershare1                       NaN
# cred_tran_nopartnershare2                       NaN
# cl_age                                           43
# GENDER_ID                                       2.0
# tran_prod                                      11.0
# tran_remont                                     0.0
# tran_inet                                       0.0
# CRED_TRAN_TOTAL                                   1
# CREDIT_TRAN_AMT_last_month                  2658.89
# CL_CHILDREN_NO                                 -1.0
# City_Population_category                   >700 тыс
# cl_income                                  600000.0
# count_tran2                                       3
# counttran1                                       13
# count_tran0                                       1
# tran_amt2                                   3370.89
# tran_amt1                                  44603.28
# tran_amt0                                      50.0
# avg_amt_prod_3m                             1853.11
# avg_amt_vnebs_3m                                NaN
# avg_amt_avto_3m                                 NaN
# avg_amt_inet_3m                                 NaN
# churn                                             0
# product_type                                    PMM
# top_cat                                    Products

# %%
# Проведем чистку данных и переведем в необходимый формат
df.withdraw0 = df.withdraw0.str.replace(',', '.').astype('float')
df.withdraw1 = df.withdraw1.str.replace(',', '.').astype('float')
df.withdraw2 = df.withdraw2.str.replace(',', '.').astype('float')

# %%
# переведем даты в формат UNIX
df['vydacha_dt'] = pd.to_datetime(df['vydacha_dt']).map(pd.Timestamp.timestamp)
df['activation_dt'] = pd.to_datetime(df['activation_dt']).map(pd.Timestamp.timestamp)

# %%
df.dtypes
# Out:
# vydacha_dt                    float64
# activation_dt                 float64
# pro0                            int64
# pro1                            int64
# pro2                            int64
# chastotta                      object
# tran_type_month0               object
# tran_type_month1               object
# tran_type_month2               object
# FREE_LIMIT0                   float64
# FREE_LIMIT1                   float64
# FREE_LIMIT2                   float64
# limit                         float64
# login_0                       float64
# login_1                       float64
# login_2                       float64
# withdraw0                     float64
# withdraw1                     float64
# withdraw2                     float64
# cred_tran_nopartnershare0     float64
# cred_tran_nopartnershare1     float64
# cred_tran_nopartnershare2     float64
# cl_age                          int64
# GENDER_ID                     float64
# tran_prod                     float64
# tran_remont                   float64
# tran_inet                     float64
# CRED_TRAN_TOTAL                 int64
# CREDIT_TRAN_AMT_last_month    float64
# CL_CHILDREN_NO                float64
# City_Population_category       object
# cl_income                     float64
# count_tran2                     int64
# counttran1                      int64
# count_tran0                     int64
# tran_amt2                     float64
# tran_amt1                     float64
# tran_amt0                     float64
# avg_amt_prod_3m               float64
# avg_amt_vnebs_3m              float64
# avg_amt_avto_3m               float64
# avg_amt_inet_3m               float64
# churn                           int64
# product_type                   object
# top_cat                        object
# dtype: object

# %%
# коэффициент оттока достаточно высокий
df.churn.value_counts(normalize=True)
# Out:
# 0    0.538959
# 1    0.461041
# Name: churn, dtype: float64

# %%
# оценим и отсортируем коэффициенты корреляции. Отрицательные значения в 'values' означают обратную корреляцию
df_cor = df.drop(['churn'], axis=1).corrwith(df.churn).to_frame('values')
df_cor = df_cor.assign(sorted = df_cor['values'].abs())
df_cor.sort_values(['sorted'], ascending=False)
# Out:
#                               values    sorted
# count_tran2                -0.311292  0.311292
# cred_tran_nopartnershare0   0.275961  0.275961
# counttran1                 -0.219043  0.219043
# tran_prod                  -0.191807  0.191807
# tran_amt2                  -0.146080  0.146080
# CRED_TRAN_TOTAL             0.133181  0.133181
# CREDIT_TRAN_AMT_last_month -0.130355  0.130355
# login_1                    -0.127832  0.127832
# login_0                    -0.123023  0.123023
# tran_inet                  -0.121541  0.121541
# login_2                    -0.116736  0.116736
# count_tran0                -0.112682  0.112682
# tran_amt1                  -0.100698  0.100698
# avg_amt_vnebs_3m            0.085506  0.085506
# cred_tran_nopartnershare2   0.076034  0.076034
# avg_amt_inet_3m             0.074151  0.074151
# cred_tran_nopartnershare1   0.061918  0.061918
# cl_age                     -0.057872  0.057872
# withdraw0                   0.056346  0.056346
# withdraw1                   0.055043  0.055043
# withdraw2                   0.052149  0.052149
# FREE_LIMIT2                -0.048190  0.048190
# FREE_LIMIT1                -0.045744  0.045744
# avg_amt_avto_3m             0.034407  0.034407
# FREE_LIMIT0                -0.032313  0.032313
# CL_CHILDREN_NO             -0.023775  0.023775
# vydacha_dt                 -0.020499  0.020499
# activation_dt               0.018436  0.018436
# tran_amt0                   0.017465  0.017465
# pro0                       -0.016424  0.016424
# GENDER_ID                   0.015991  0.015991
# avg_amt_prod_3m             0.014972  0.014972
# tran_remont                -0.014734  0.014734
# limit                      -0.011353  0.011353
# pro1                       -0.008362  0.008362
# pro2                        0.003882  0.003882
# cl_income                  -0.001682  0.001682

# %%
# проведем подготовку датасета для моделирования. Унифицируем данные. Переведем категориальные переменные в числовые
df.columns = df.columns.str.lower().str.replace(' ', '_')

categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)

for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')

# %%
df.isnull().sum()
# Out:
# vydacha_dt                        0
# activation_dt                     0
# pro0                              0
# pro1                              0
# pro2                              0
# chastotta                         0
# tran_type_month0                  0
# tran_type_month1                  0
# tran_type_month2                  0
# free_limit0                       2
# free_limit1                       2
# free_limit2                       2
# limit                             0
# login_0                         116
# login_1                         585
# login_2                        1062
# withdraw0                         0
# withdraw1                         0
# withdraw2                         0
# cred_tran_nopartnershare0      6923
# cred_tran_nopartnershare1      4853
# cred_tran_nopartnershare2      4589
# cl_age                            0
# gender_id                         1
# tran_prod                       315
# tran_remont                     315
# tran_inet                       315
# cred_tran_total                   0
# credit_tran_amt_last_month     3327
# cl_children_no                    1
# city_population_category        890
# cl_income                         0
# count_tran2                       0
# counttran1                        0
# count_tran0                       0
# tran_amt2                         0
# tran_amt1                         0
# tran_amt0                         0
# avg_amt_prod_3m                5006
# avg_amt_vnebs_3m               1518
# avg_amt_avto_3m               10479
# avg_amt_inet_3m                9044
# churn                             0
# product_type                      0
# top_cat                        1296
# dtype: int64

# %%
df = df.fillna(0)

# %%
# разделим датасет на обучающую, валидационную и тестовую выборки
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=25)
df_train, df_val = train_test_split(df_train_full, test_size=0.33, random_state=25)

y_train = df_train.churn.values
y_val = df_val.churn.values

del df_train['churn']
del df_val['churn']

# %%
categorical = list(df_train.dtypes[df.dtypes == 'object'].index)
numerical = list(df_train.dtypes[df.dtypes != 'object'].index)

# %%
# применим one-hot-encoding
dv = DictVectorizer(sparse=False)

train_dict = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
# Модель логистическая регрессия
lr = LogisticRegression(solver='liblinear', random_state=1)
lr.fit(X_train, y_train)

y_pred_lr = lr.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred_lr)
print('train auc: %.3f' % auc)

y_pred_lr = lr.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred_lr)
print('val auc: %.3f' % auc)
# Out:
# train auc: 0.494
# val auc: 0.486

# %%
# Модель Random Forest
rf = RandomForestClassifier(max_depth = 20, min_samples_leaf = 5, n_estimators=180, random_state=3)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred_rf)
print('train auc: %.3f' % auc)

y_pred_rf = rf.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred_rf)
print('val auc: %.3f' % auc)
# Out:
# train auc: 0.976
# val auc: 0.770

# %%
# Подбор параметров Random Forest, наилучшая оценка модели
params = {
    "max_depth": [1, 2, 3, 4, 5, 6, 10, 15, 20],
    "min_samples_leaf": [1, 5, 10, 15, 20, 50, 100, 200]
}
gs = GridSearchCV(rf, params, scoring='roc_auc')
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(max_depth=20, min_samples_leaf=5,
#                                               n_estimators=180,
#                                               random_state=3),
#              param_grid={'max_depth': [1, 2, 3, 4, 5, 6, 10, 15, 20],
#                          'min_samples_leaf': [1, 5, 10, 15, 20, 50, 100, 200]},
#              scoring='roc_auc')

# %%
print('Best parameters: ' + str(gs.best_params_))
print('ROC-AUC ' + str(gs.best_score_))
# Out:
# Best parameters: {'max_depth': 20, 'min_samples_leaf': 5}
# ROC-AUC 0.7749956428431469

# %%
# Модель градиентного бустинга XGBoost 
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)

xgb_params = {
    'eta': 0.1,
    'max_depth': 3,
    'min_child_weight': 1,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread': 8,
    'seed': 1,
}

model = xgb.train(xgb_params, dtrain,
                  num_boost_round=180)

# %%
y_pred_xgb = model.predict(dtrain)
auc = roc_auc_score(y_train, y_pred_xgb)
print('train auc: %.3f' % auc)

y_pred_xgb = model.predict(dval)
auc = roc_auc_score(y_val, y_pred_xgb)
print('val auc: %.3f' % auc)
# Out:
# train auc: 0.859
# val auc: 0.771

# %%
# анализ feature_importances согласно модели Random Forest
importances = list(zip(dv.feature_names_, rf.feature_importances_))

df_importance = pd.DataFrame(importances, columns=['feature', 'gain'])
df_importance = df_importance.sort_values(by='gain', ascending=False)
df_importance.head(10)
# Out:
#                        feature      gain
# 17                 count_tran2  0.096922
# 74                   tran_amt2  0.082053
# 18                  counttran1  0.049455
# 26                 free_limit2  0.043306
# 4             avg_amt_vnebs_3m  0.041450
# 73                   tran_amt1  0.040687
# 76                   tran_prod  0.035431
# 3              avg_amt_prod_3m  0.034198
# 23  credit_tran_amt_last_month  0.033432
# 72                   tran_amt0  0.030639

# %%
# df_rfm = pd.read_csv(f'/content/in_actions.csv', index_col=0)
df_rfm = df_rfm.fillna(0)

# %%
main_features = [
    'count_tran2', 
    'tran_amt2',
    'counttran1',
    'tran_amt1',
    'tran_prod',
    'CREDIT_TRAN_AMT_last_month',
    'login_0',
    'login_1',
    'login_2',
    'tran_inet'
]

# %%
# проанализируем ушедших клиентов, определим условные сигнальные контрольные точки через медиану
df_exited = df_rfm[df_rfm.churn == 0]
df_exited[main_features].describe()
# Out:
#        count_tran2      tran_amt2   counttran1     tran_amt1    tran_prod  \
# count   7000.00000    7000.000000  7000.000000  7.000000e+03  7000.000000
# mean      20.31500   19949.773180    23.442000  2.675600e+04     7.559857
# std       21.87057   25772.320535    24.468531  3.475921e+04    12.086575
# min        1.00000       0.440000     1.000000  9.000000e+00     0.000000
# 25%        6.00000    5496.075000     6.000000  7.822020e+03     1.000000
# 50%       13.00000   12326.180000    16.000000  1.668219e+04     3.000000
# 75%       27.00000   25085.202500    32.000000  3.475736e+04    10.000000
# max      233.00000  596125.220000   291.000000  1.033570e+06   171.000000
#
#        CREDIT_TRAN_AMT_last_month      login_0      login_1      login_2  \
# count                 7000.000000  7000.000000  7000.000000  7000.000000
# mean                 11336.246511    10.691143    12.908429    12.667429
# std                  17717.724025    12.240274    13.610760    15.640809
# min                      0.000000     0.000000     0.000000     0.000000
# 25%                      0.000000     3.000000     4.000000     4.000000
# 50%                   4437.550000     7.000000     9.000000    10.000000
# 75%                  15693.630000    14.000000    17.000000    16.000000
# max                 251096.600000   305.000000   195.000000   502.000000
#
#          tran_inet
# count  7000.000000
# mean      3.264714
# std       8.397610
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       3.000000
# max     150.000000

# %%
# проведем RFM сегментацию на имеющихся данных
# добавим столбцы R, F, M, характеризующие давность, частоту и общую стоимость
# добавим общий индекс RFM

# %%
# расчет частоты и стоимости

df_rfm = df_rfm.assign(frequency = df_rfm['count_tran0'] + df_rfm['counttran1'] + df_rfm['count_tran2'])
df_rfm = df_rfm.assign(monetary = df_rfm['tran_amt0'] + df_rfm['tran_amt1'] + df_rfm['tran_amt2'])

# %%
# Оценим распределение показателей RFM. Для разделения на группы по частоте и стоимости будем использовать перцентили.
# Группа 1: 0 - 25%
# Группа 2: 25 - 75%
# Группа 3: 75 - 100%
df_rfm[list(['count_tran2', 'frequency', 'monetary'])].describe()
# Out:
#         count_tran2     frequency      monetary
# count  12988.000000  12988.000000  1.298800e+04
# mean      14.845473     46.790499  7.425269e+04
# std       18.997921     46.311910  7.786537e+04
# min        1.000000      3.000000  3.000000e+01
# 25%        3.000000     15.000000  3.352569e+04
# 50%        8.000000     32.000000  5.710929e+04
# 75%       19.000000     62.000000  9.038397e+04
# max      233.000000    556.000000  2.466512e+06

# %%
# Определение групп по давности. Используем данные порогового значения по количеству транзакций за 3 месяц. 
def calculate_r(series):
  if series == 1: 
    return 1
  elif 1 < series <= 13:
    return 2
  elif series > 13:
    return 3

# %%
# Определение групп по частоте
def calculate_f(series):
  if 0 < series <= 15:
    return 1
  elif 15 < series <= 62:
    return 2
  elif series > 62:
    return 3

# %%
# Определение групп по стоимости
def calculate_m(series):
  if 0 < series <= 33500:
    return 1
  elif 33500 < series <= 90000:
    return 2
  elif series > 90000:
    return 3

# %%
# Добавим данные в датасет
df_rfm['R'] = df_rfm['count_tran2'].apply(calculate_r).astype(str)
df_rfm['F'] = df_rfm['frequency'].apply(calculate_f).astype(str)
df_rfm['M'] = df_rfm['monetary'].apply(calculate_m).astype(str)

df_rfm['RFM'] = df_rfm.R + df_rfm.F + df_rfm.M

# %%
# оценим каких категорий пользователей большей всего.
df_rfm.RFM.value_counts().sort_values(ascending=False)
# Out:
# 222    2005
# 333    1265
# 332    1172
# 221    1162
# 212    1006
# 322     975
# 223     809
# 211     794
# 112     679
# 111     490
# 321     474
# 323     434
# 232     312
# 213     287
# 122     280
# 233     208
# 331     159
# 113     145
# 121     128
# 123      99
# 132      43
# 231      34
# 133      25
# 131       3
# Name: RFM, dtype: int64

# %%
# оценим и отсортируем коэффициенты корреляции для каждой из групп RFM

for group in df_rfm.RFM.unique():
  df_cor_rfm = df_rfm[df_rfm['RFM'] == group]
  df_cor_values = df_cor_rfm.drop(['churn'], axis=1).corrwith(df_cor_rfm.churn).to_frame('values')
  df_cor_values = df_cor_values.assign(sorted = df_cor_values['values'].abs())
  df_cor_values = df_cor_values.sort_values(['sorted'], ascending=False)
  print(group)
  print(df_cor_values.head(5))
  print(' ')
# Out:
# 321
#                              values    sorted
# tran_prod                 -0.116960  0.116960
# cred_tran_nopartnershare2  0.116592  0.116592
# counttran1                -0.115627  0.115627
# tran_amt0                  0.100098  0.100098
# frequency                 -0.097579  0.097579
#
# 222
#                              values    sorted
# count_tran2               -0.210198  0.210198
# cred_tran_nopartnershare0  0.178675  0.178675
# FREE_LIMIT2               -0.128725  0.128725
# cred_tran_nopartnershare1  0.122315  0.122315
# cred_tran_nopartnershare2  0.121861  0.121861
#
# 333
#                              values    sorted
# cred_tran_nopartnershare0  0.189292  0.189292
# count_tran2               -0.175462  0.175462
# login_1                   -0.156986  0.156986
# cred_tran_nopartnershare1  0.153102  0.153102
# cred_tran_nopartnershare2  0.149764  0.149764
#
# 212
#                values    sorted
# frequency   -0.113909  0.113909
# pro1        -0.108174  0.108174
# pro0        -0.107974  0.107974
# count_tran2 -0.091800  0.091800
# pro2        -0.087980  0.087980
#
# 111
#                    values    sorted
# tran_amt0        0.101250  0.101250
# cl_age          -0.085306  0.085306
# login_1         -0.066633  0.066633
# CRED_TRAN_TOTAL  0.066378  0.066378
# avg_amt_avto_3m -0.065143  0.065143
#
# 221
#                              values    sorted
# count_tran2               -0.260037  0.260037
# tran_amt2                 -0.221379  0.221379
# cred_tran_nopartnershare2  0.213088  0.213088
# cred_tran_nopartnershare1  0.202557  0.202557
# cred_tran_nopartnershare0  0.186932  0.186932
#
# 332
#                              values    sorted
# cred_tran_nopartnershare0  0.252205  0.252205
# FREE_LIMIT2               -0.233985  0.233985
# cred_tran_nopartnershare2  0.233305  0.233305
# FREE_LIMIT1               -0.212502  0.212502
# cred_tran_nopartnershare1  0.212252  0.212252
#
# 132
#                    values    sorted
# pro1            -0.317295  0.317295
# login_0          0.299820  0.299820
# pro0            -0.269896  0.269896
# monetary        -0.268562  0.268562
# avg_amt_inet_3m -0.219717  0.219717
#
# 112
#                    values    sorted
# counttran1      -0.127531  0.127531
# FREE_LIMIT2     -0.102808  0.102808
# frequency       -0.093808  0.093808
# tran_amt2        0.090192  0.090192
# CRED_TRAN_TOTAL  0.079383  0.079383
#
# 113
#                              values    sorted
# cred_tran_nopartnershare2 -0.297374  0.297374
# cred_tran_nopartnershare1 -0.276930  0.276930
# pro2                      -0.226799  0.226799
# login_0                    0.167582  0.167582
# CL_CHILDREN_NO            -0.154234  0.154234
#
# 223
#                   values    sorted
# count_tran2    -0.216329  0.216329
# pro0           -0.102298  0.102298
# CL_CHILDREN_NO -0.079699  0.079699
# pro1           -0.078587  0.078587
# frequency      -0.071064  0.071064
#
# 123
#                               values    sorted
# GENDER_ID                   0.247292  0.247292
# CRED_TRAN_TOTAL             0.242121  0.242121
# tran_remont                -0.211749  0.211749
# tran_inet                  -0.190657  0.190657
# CREDIT_TRAN_AMT_last_month  0.149432  0.149432
#
# 322
#                              values    sorted
# cred_tran_nopartnershare2  0.239824  0.239824
# cred_tran_nopartnershare1  0.184788  0.184788
# cred_tran_nopartnershare0  0.131878  0.131878
# tran_prod                 -0.121738  0.121738
# CRED_TRAN_TOTAL            0.110354  0.110354
#
# 211
#                              values    sorted
# cl_age                    -0.118247  0.118247
# count_tran2               -0.115227  0.115227
# cred_tran_nopartnershare0  0.113665  0.113665
# frequency                 -0.090022  0.090022
# cl_income                  0.077960  0.077960
#
# 121
#                              values    sorted
# tran_amt1                 -0.240533  0.240533
# tran_amt0                  0.229286  0.229286
# login_1                    0.226838  0.226838
# cred_tran_nopartnershare0  0.223883  0.223883
# avg_amt_prod_3m           -0.156977  0.156977
#
# 213
#              values    sorted
# tran_amt2  0.162221  0.162221
# cl_income  0.140239  0.140239
# login_2   -0.116439  0.116439
# monetary   0.103641  0.103641
# tran_inet -0.102512  0.102512
#
# 232
#                              values    sorted
# cred_tran_nopartnershare0  0.231499  0.231499
# GENDER_ID                  0.174234  0.174234
# tran_amt2                 -0.154219  0.154219
# frequency                 -0.146117  0.146117
# tran_prod                 -0.135965  0.135965
#
# 323
#                              values    sorted
# frequency                 -0.167690  0.167690
# cred_tran_nopartnershare0  0.161333  0.161333
# tran_prod                 -0.159909  0.159909
# counttran1                -0.143797  0.143797
# login_1                   -0.132370  0.132370
#
# 331
#                              values    sorted
# cred_tran_nopartnershare1  0.306535  0.306535
# cred_tran_nopartnershare0  0.300195  0.300195
# cred_tran_nopartnershare2  0.238874  0.238874
# frequency                 -0.189986  0.189986
# CRED_TRAN_TOTAL            0.189888  0.189888
#
# 122
#                              values    sorted
# login_2                    0.105726  0.105726
# cl_age                    -0.104141  0.104141
# cred_tran_nopartnershare2 -0.094650  0.094650
# tran_amt2                  0.089627  0.089627
# avg_amt_vnebs_3m          -0.089132  0.089132
#
# 233
#                               values    sorted
# cl_income                   0.147997  0.147997
# CREDIT_TRAN_AMT_last_month -0.142458  0.142458
# tran_amt2                  -0.117548  0.117548
# pro0                       -0.115632  0.115632
# tran_remont                 0.113377  0.113377
#
# 133
#                               values    sorted
# FREE_LIMIT1                -0.317130  0.317130
# FREE_LIMIT2                -0.301784  0.301784
# cl_age                     -0.282191  0.282191
# CREDIT_TRAN_AMT_last_month -0.270594  0.270594
# tran_inet                  -0.265591  0.265591
#
# 231
#              values    sorted
# login_1   -0.514550  0.514550
# tran_prod -0.486375  0.486375
# login_0   -0.416292  0.416292
# login_2   -0.354092  0.354092
# tran_amt2 -0.327365  0.327365
#
# 131
#              values  sorted
# pro0            NaN     NaN
# pro1            NaN     NaN
# pro2            NaN     NaN
# FREE_LIMIT0     NaN     NaN
# FREE_LIMIT1     NaN     NaN
